# %% [markdown]
# # RobotPM_MLOps.ipynb
#
# ## What changed vs the original streaming workshop?
# - Added modular `src/` architecture (separation of concerns)
# - Added YAML config (`configs/experiment_config.yaml`) for parameterized runs
# - Added experiment tracking (`experiments/results.csv`)
# - Added reproducible processed dataset output (`data/processed/`)
# - Added dashboard app (`dashboard/app.py`) for live monitoring + alerting
#
# ## Recommended Additions
# - CI checks (lint/test), model registry, data validation
#
# ## Recommended Enhancements
# - Replace engineered failure labels with real maintenance logs
# - Add multivariate regression / regularization
# - Add drift detection + retraining triggers

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent  # notebooks/ -> project root
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

print("Project root added:", PROJECT_ROOT)

import pandas as pd
df = pd.read_csv('../data/processed/processed_robot_data.csv')
df[['robot_id','Time','failure_event','time_to_failure_days']].tail(10)
# Out:
#        robot_id                              Time  failure_event  \
# 119006  robot_3  2022-10-18 10:44:41.620000+00:00              0
# 119007  robot_3  2022-10-18 10:44:43.487000+00:00              0
# 119008  robot_3  2022-10-18 10:44:45.409000+00:00              0
# 119009  robot_3  2022-10-18 10:44:47.238000+00:00              0
# 119010  robot_3  2022-10-18 10:44:49.176000+00:00              0
# 119011  robot_3  2022-10-18 10:44:51.049000+00:00              0
# 119012  robot_3  2022-10-18 10:44:52.988000+00:00              0
# 119013  robot_3  2022-10-18 10:44:54.838000+00:00              0
# 119014  robot_3  2022-10-18 10:44:56.706000+00:00              0
# 119015  robot_3  2022-10-18 10:44:58.628000+00:00              0
#
#         time_to_failure_days
# 119006              0.021675
# 119007              0.021675
# 119008              0.021675
# 119009              0.021675
# 119010              0.021675
# 119011              0.021675
# 119012              0.021675
# 119013              0.021675
# 119014              0.021675
# 119015              0.021675
