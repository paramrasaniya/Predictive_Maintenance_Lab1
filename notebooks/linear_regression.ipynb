# %% [markdown]
# # linear_regression.ipynb
# Manual LR vs scikit-learn comparison.

# %%
# Out:
# c:\Users\ksuma\LinearRegressionArchitecture_Workshop1\notebooks
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 5
#       2 print(os.getcwd())
#       4 from src.run_experiment import main
# ----> 5 main()
#
# File c:\Users\ksuma\LinearRegressionArchitecture_Workshop1\src\run_experiment.py:30, in main()
#      28 def main():
#      29     cfg_path = "configs/experiment_config.yaml"
# ---> 30     with open(cfg_path, "r", encoding="utf-8") as f:
#      31         cfg = yaml.safe_load(f)
#      33     run_tag = cfg["project"]["run_tag"]
#
# FileNotFoundError: [Errno 2] No such file or directory: 'configs/experiment_config.yaml'

# %%
import os
from pathlib import Path

# Move working directory to project root (one level above notebooks/)
os.chdir(Path.cwd().parent)

print("Now running from:", os.getcwd())

# %%
from src.run_experiment import main
main()
